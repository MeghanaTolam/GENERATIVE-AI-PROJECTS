# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanaTolam/GENERATIVE-AI-PROJECTS/blob/main/Sentence_similarity_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer, util

# load the  model
model=SentenceTransformer('all-MiniLM-L6-v2')

#take input from user
text1=input("Enter the text1: ")
text2=input("Enter the text2: ")

#convert text to embeddings
embedding1=model.encode(text1)
embedding2=model.encode(text2)

#calculate similarity
similarity=util.cos_sim(embedding1,embedding2)

#show result
print("\n similarity score:",round(float(similarity),2))

if similarity>0.75:
  print("similarity level:high")
elif similarity>0.5:
  print("similarity level:medium")
else:
  print("similarity level:low")
# Out:
# Enter the text1: mango is a animal
# Enter the text2: mango is a thing
#
#  similarity score: 0.78
# similarity level:high

# %%
()
# Out:
# ()
